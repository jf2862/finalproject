# %% [markdown]
# # Read Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm

# %%
audusd=pd.read_csv('data/australia/CURRFX-AUDUSD.csv')
audusd['Date'] = pd.to_datetime(audusd['Date'])
audusd=audusd.rename(columns = {'Rate':'AUD/USD'})

# %%
oil=pd.read_csv('data/commodity/Crude oil.csv')
oil=oil.rename(columns = {'[DateTime]':'Date',' [Close]':'Crude Oil Price'})
oil['Date'] = pd.to_datetime(oil['Date'])

# %%
iron=pd.read_csv('data/commodity/Iron Ore.csv')
iron=iron.rename(columns = {'[DateTime]':'Date',' [Close]':'Iron Ore Price'})
iron['Date'] = pd.to_datetime(iron['Date'])

# %%
aluminum=pd.read_csv('data/commodity/Aluminum.csv')
aluminum=aluminum.rename(columns = {'[DateTime]':'Date',' [Close]':'Aluminum Price'})
aluminum['Date'] = pd.to_datetime(aluminum['Date'])

# %%
australia_inflation=pd.read_csv('data/australia/Australia Core Inflation Rate.csv')
australia_inflation=australia_inflation.rename(columns = {'[DateTime]':'Date',' [Close]':'Australia Inflation Rate'})
australia_inflation['Date'] = pd.to_datetime(australia_inflation['Date'])

# %%
australia_stock=pd.read_csv('data/australia/Australia ASX 200 Stock Market Index.csv')
australia_stock=australia_stock.rename(columns = {'[DateTime]':'Date',' [Close]':'Stock Market Index'})
australia_stock['Date'] = pd.to_datetime(australia_stock['Date'])

# %%
australia_gdp_growth=pd.read_csv('data/australia/Australia GDP Growth Rate.csv')
australia_gdp_growth=australia_gdp_growth.rename(columns = {'[DateTime]':'Date',' [Close]':'GDP Growth Rate'})
australia_gdp_growth['Date'] = pd.to_datetime(australia_gdp_growth['Date'])

# %%
australia_bot=pd.read_csv('data/australia/Australia Balance of Trade.csv')
australia_bot=australia_bot.rename(columns = {'[DateTime]':'Date',' [Close]':'Balance of Trade'})
australia_bot['Date'] = pd.to_datetime(australia_bot['Date'])

# %%
australia_interest_rate=pd.read_csv('data/australia/Australia Interest Rate.csv')
australia_interest_rate=australia_interest_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'Interest Rate'})
australia_interest_rate['Date'] = pd.to_datetime(australia_interest_rate['Date'])

# %%
usdx=pd.read_csv('data/United States Dollar.csv')
usdx=usdx.rename(columns = {'[DateTime]':'Date',' [Close]':'USDX'})
usdx['Date'] = pd.to_datetime(usdx['Date'])

# %%
us_federal_fund_rate=pd.read_csv('data/United States Fed Funds Rate.csv')
us_federal_fund_rate=us_federal_fund_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'US Fed Funds Rate'})
us_federal_fund_rate['Date'] = pd.to_datetime(us_federal_fund_rate['Date'])

# %% [markdown]
# # Merge data

# %%
aud_oil=audusd.merge(oil)
aud_oil_al=aud_oil.merge(aluminum)
aud_commodity=aud_oil_al.merge(iron)
aud_commodity
# Out:
#            Date   AUD/USD  Crude Oil Price  Aluminum Price  Iron Ore Price
# 0    2016-03-04  0.736044            36.30         1586.50            52.4
# 1    2016-03-03  0.728705            34.73         1575.00            51.7
# 2    2016-03-02  0.720157            34.63         1590.50            51.6
# 3    2016-03-01  0.714496            33.86         1579.00            50.4
# 4    2016-02-29  0.716315            33.85         1572.00            48.9
# 1086 2012-01-03  1.028240           102.96         2054.50           138.3
# 1087 2012-01-02  1.020430            98.83         1994.50           138.5
#
# [1088 rows x 5 columns]

# %%
aud_commodity_inf=aud_commodity.merge(australia_inflation, how='outer')
aud_commodity_inf_stock=aud_commodity_inf.merge(australia_stock)
aud_commodity_inf_stock_gdp=aud_commodity_inf_stock.merge(australia_gdp_growth, how='outer')
aud_commodity_inf_stock_gdp_bot=aud_commodity_inf_stock_gdp.merge(australia_bot, how='outer')
aud_commodity_inf_stock_gdp_bot_interest=aud_commodity_inf_stock_gdp_bot.merge(australia_interest_rate, how='outer')
aud_commodity_inf_stock_gdp_bot_interest_usfund=aud_commodity_inf_stock_gdp_bot_interest.merge(us_federal_fund_rate, how='outer')
aud_all=aud_commodity_inf_stock_gdp_bot_interest_usfund.merge(usdx)

# %% [markdown]
# # set date as index

# %%
aud_all=aud_all.sort_values('Date', ascending=False)

# %%
aud_all=aud_all.set_index('Date')

# %% [markdown]
# # Fill all NaNs and drop unwanted rows

# %%
aud_all['Australia Inflation Rate']=aud_all['Australia Inflation Rate'].fillna(method='ffill')
aud_all['GDP Growth Rate']=aud_all['GDP Growth Rate'].fillna(method='ffill')
aud_all['Balance of Trade']=aud_all['Balance of Trade'].fillna(method='ffill')
aud_all['Interest Rate']=aud_all['Interest Rate'].fillna(method='bfill')
aud_all['US Fed Funds Rate']=aud_all['US Fed Funds Rate'].fillna(method='bfill')

# %%
aud_all.dropna(inplace=True)
aud_all
# Out:
#              AUD/USD  Crude Oil Price  Aluminum Price  Iron Ore Price  \
# Date
# 2015-12-31  0.729516            37.04         1501.00            42.9
# 2015-12-30  0.728334            36.60         1534.00            42.5
# 2015-12-29  0.727007            37.87         1525.00            41.4
# 2015-12-28  0.726536            36.81         1532.00            40.5
# 2015-12-24  0.724828            38.10         1540.50            40.2
# 2015-12-23  0.722751            37.50         1543.00            40.2
# 2015-12-22  0.720323            36.14         1506.50            40.2
# 2015-12-21  0.716146            34.74         1515.00            39.4
# 2015-12-18  0.715615            34.73         1506.00            39.3
# 2015-12-17  0.718329            34.95         1476.00            38.5
# 2015-12-16  0.721318            35.52         1486.00            38.2
# 2015-12-15  0.722335            37.35         1471.00            37.5
# 2015-12-14  0.721894            36.31         1491.50            37.5
# 2015-12-11  0.725273            35.62         1482.00            37.0
# 2015-12-10  0.726105            36.76         1491.00            37.5
# 2015-12-09  0.722106            37.16         1490.00            38.3
# 2015-12-08  0.725953            37.51         1477.00            38.8
# 2015-12-07  0.731552            37.65         1485.00            38.9
# 2015-12-04  0.732597            39.97         1514.50            39.4
# 2015-12-03  0.730287            41.08         1473.00            40.3
# 2015-12-02  0.730287            39.94         1485.50            40.6
# 2015-12-01  0.725213            41.85         1469.00            41.6
# 2015-11-30  0.720719            41.65         1446.00            42.8
# 2015-11-27  0.721744            41.71         1457.50            43.5
# 2015-11-26  0.724183            42.46         1501.00            43.6
# 2015-11-25  0.724073            43.04         1460.00            43.4
# 2015-11-24  0.720441            42.87         1446.00            43.4
# 2015-11-23  0.719954            41.75         1435.50            44.2
# 2015-11-20  0.719416            40.39         1447.00            45.0
# 2012-03-07              -728           4.25               0.25   79.710
# 2012-03-06              -728           4.25               0.25   79.870
# 2012-03-05              -728           4.25               0.25   79.300
# 2012-03-02              -728           4.25               0.25   79.400
# 2012-03-01              -728           4.25               0.25   78.790
# 2012-02-29             -1014           4.25               0.25   78.740
# 2012-02-28             -1014           4.25               0.25   78.270
# 2012-02-27             -1014           4.25               0.25   78.570
# 2012-02-24             -1014           4.25               0.25   78.350
# 2012-02-23             -1014           4.25               0.25   78.820
# 2012-02-22             -1014           4.25               0.25   79.210
# 2012-02-21             -1014           4.25               0.25   79.040
# 2012-02-20             -1014           4.25               0.25   79.330
# 2012-02-17             -1014           4.25               0.25   79.330
# 2012-02-16             -1014           4.25               0.25   79.350
# 2012-02-15             -1014           4.25               0.25   79.670
# 2012-02-14             -1014           4.25               0.25   79.580
# 2012-02-13             -1014           4.25               0.25   78.950
# 2012-02-10             -1014           4.25               0.25   79.110
# 2012-02-09             -1014           4.25               0.25   78.570
# 2012-02-08             -1014           4.25               0.25   78.640
# 2012-02-07             -1014           4.25               0.25   78.580
# 2012-02-06             -1014           4.25               0.25   79.070
# 2012-02-03             -1014           4.25               0.25   78.920
# 2012-02-02             -1014           4.25               0.25   78.990
# 2012-02-01             -1014           4.25               0.25   78.920
# 2012-01-31             -2624           4.25               0.25   79.290
#
# [1022 rows x 11 columns]

# %% [markdown]
# # Save as csv

# %%
aud_all.to_csv('australia.csv')

# %%
X = aud_all['Crude Oil Price']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     1994.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          3.52e-242
# Time:                        23:40:47   Log-Likelihood:                 1347.2
# No. Observations:                1022   AIC:                            -2690.
# Df Residuals:                    1020   BIC:                            -2681.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.5711      0.008     72.228      0.000         0.556     0.587
# Crude Oil Price     0.0041   9.19e-05     44.649      0.000         0.004     0.004
# ==============================================================================
# Omnibus:                      460.122   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.189
# Skew:                           0.319   Prob(JB):                     3.48e-16
# Kurtosis:                       1.875   Cond. No.                         336.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['Aluminum Price']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     1248.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          3.68e-179
# Time:                        23:40:47   Log-Likelihood:                 1201.9
# No. Observations:                1022   AIC:                            -2400.
# Df Residuals:                    1020   BIC:                            -2390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const              0.0157      0.025      0.614      0.539        -0.034     0.066
# Aluminum Price     0.0005   1.37e-05     35.323      0.000         0.000     0.001
# ==============================================================================
# Omnibus:                      117.487   Durbin-Watson:                   0.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.692
# Skew:                          -0.236   Prob(JB):                     1.46e-09
# Kurtosis:                       2.144   Cond. No.                     2.02e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = aud_all['Iron Ore Price']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     3030.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          1.04e-307
# Time:                        23:40:47   Log-Likelihood:                 1498.3
# No. Observations:                1022   AIC:                            -2993.
# Df Residuals:                    1020   BIC:                            -2983.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const              0.6243      0.006    113.153      0.000         0.613     0.635
# Iron Ore Price     0.0028   5.07e-05     55.050      0.000         0.003     0.003
# ==============================================================================
# Omnibus:                        8.972   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.114
# Skew:                           0.230   Prob(JB):                       0.0105
# Kurtosis:                       2.960   Cond. No.                         343.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['Australia Inflation Rate']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     329.1
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           5.92e-64
# Time:                        23:40:47   Log-Likelihood:                 936.49
# No. Observations:                1022   AIC:                            -1869.
# Df Residuals:                    1020   BIC:                            -1859.
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------
# const                        0.3534      0.031     11.411      0.000         0.293     0.414
# Australia Inflation Rate     0.2382      0.013     18.140      0.000         0.212     0.264
# ==============================================================================
# Omnibus:                        0.059   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.971   Jarque-Bera (JB):               95.001
# Skew:                          -0.019   Prob(JB):                     2.35e-21
# Kurtosis:                       1.507   Cond. No.                         28.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['Stock Market Index']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     900.9
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          2.31e-142
# Time:                        23:40:48   Log-Likelihood:                 1117.1
# No. Observations:                1022   AIC:                            -2230.
# Df Residuals:                    1020   BIC:                            -2220.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# const                  1.6868      0.026     65.060      0.000         1.636     1.738
# Stock Market Index    -0.0002   5.07e-06    -30.014      0.000        -0.000    -0.000
# ==============================================================================
# Omnibus:                      104.445   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.078
# Skew:                          -0.870   Prob(JB):                     4.66e-30
# Kurtosis:                       3.384   Cond. No.                     5.22e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.22e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = aud_all['GDP Growth Rate']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     202.3
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           5.09e-42
# Time:                        23:40:48   Log-Likelihood:                 886.08
# No. Observations:                1022   AIC:                            -1768.
# Df Residuals:                    1020   BIC:                            -1758.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               1.0372      0.009    111.116      0.000         1.019     1.056
# GDP Growth Rate    -0.2119      0.015    -14.224      0.000        -0.241    -0.183
# ==============================================================================
# Omnibus:                      110.407   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.531
# Skew:                          -0.571   Prob(JB):                     8.86e-18
# Kurtosis:                       2.264   Cond. No.                         6.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['Balance of Trade']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     160.9
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           2.42e-34
# Time:                        23:40:49   Log-Likelihood:                 868.46
# No. Observations:                1022   AIC:                            -1733.
# Df Residuals:                    1020   BIC:                            -1723.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                0.9678      0.005    178.016      0.000         0.957     0.978
# Balance of Trade  3.549e-05    2.8e-06     12.685      0.000         3e-05   4.1e-05
# ==============================================================================
# Omnibus:                      887.255   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.160
# Skew:                           0.070   Prob(JB):                     1.17e-14
# Kurtosis:                       1.781   Cond. No.                     3.26e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = aud_all['Interest Rate']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     2426.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          6.50e-272
# Time:                        23:40:49   Log-Likelihood:                 1415.7
# No. Observations:                1022   AIC:                            -2827.
# Df Residuals:                    1020   BIC:                            -2818.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# const             0.4913      0.009     56.106      0.000         0.474     0.508
# Interest Rate     0.1544      0.003     49.257      0.000         0.148     0.161
# ==============================================================================
# Omnibus:                     1015.785   Durbin-Watson:                   0.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.858
# Skew:                          -0.188   Prob(JB):                     4.11e-16
# Kurtosis:                       1.766   Cond. No.                         14.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['US Fed Funds Rate']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     33.25
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           1.07e-08
# Time:                        23:40:49   Log-Likelihood:                 810.01
# No. Observations:                1022   AIC:                            -1616.
# Df Residuals:                    1020   BIC:                            -1606.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# const                 1.1061      0.034     32.754      0.000         1.040     1.172
# US Fed Funds Rate    -0.7666      0.133     -5.766      0.000        -1.028    -0.506
# ==============================================================================
# Omnibus:                      238.296   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.650
# Skew:                          -0.394   Prob(JB):                     1.24e-15
# Kurtosis:                       2.005   Cond. No.                         41.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = aud_all['USDX']
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.777
# Method:                 Least Squares   F-statistic:                     3565.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:40:50   Log-Likelihood:                 1561.7
# No. Observations:                1022   AIC:                            -3119.
# Df Residuals:                    1020   BIC:                            -3109.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          2.1455      0.021    103.561      0.000         2.105     2.186
# USDX          -0.0145      0.000    -59.710      0.000        -0.015    -0.014
# ==============================================================================
# Omnibus:                      303.474   Durbin-Watson:                   0.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.271
# Skew:                           0.045   Prob(JB):                     3.30e-11
# Kurtosis:                       1.939   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = aud_all.drop(['AUD/USD'], axis=1)
y = aud_all['AUD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                AUD/USD   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     1509.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:40:50   Log-Likelihood:                 2208.1
# No. Observations:                1022   AIC:                            -4394.
# Df Residuals:                    1011   BIC:                            -4340.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------
# const                        1.3096      0.079     16.621      0.000         1.155     1.464
# Crude Oil Price             -0.0008      0.000     -5.263      0.000        -0.001    -0.001
# Aluminum Price            7.989e-05   1.27e-05      6.309      0.000       5.5e-05     0.000
# Iron Ore Price               0.0010   6.33e-05     15.797      0.000         0.001     0.001
# Australia Inflation Rate     0.0171      0.008      2.185      0.029         0.002     0.032
# Stock Market Index        6.271e-06   4.97e-06      1.261      0.207     -3.48e-06   1.6e-05
# GDP Growth Rate             -0.0377      0.006     -6.206      0.000        -0.050    -0.026
# Balance of Trade         -1.429e-05   1.28e-06    -11.144      0.000     -1.68e-05 -1.18e-05
# Interest Rate                0.0529      0.005     10.490      0.000         0.043     0.063
# US Fed Funds Rate           -0.0189      0.036     -0.530      0.596        -0.089     0.051
# USDX                        -0.0093      0.001    -14.073      0.000        -0.011    -0.008
# ==============================================================================
# Omnibus:                       87.472   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.692
# Skew:                           0.743   Prob(JB):                     1.52e-24
# Kurtosis:                       3.604   Cond. No.                     5.12e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('Kj2921812', 'exatkr0578')

# %%
audusd.head()

trace = go.Scatter( x=audusd['Date'], y=audusd['AUD/USD'] )
data = [trace]

url = py.plot(data, filename='AUD/USD from 2012 to now')

# %%
aud_alloil = aud_all['Crude Oil Price']
aud_alljpy = aud_all['AUD/USD']
aud_all.head(2)

fig = {
    'data': [
  		{
  			'x': aud_alloil, 
        	'y': aud_alljpy, 
        	'text': aud_all.index, 
        	'mode': 'markers', 
        	'name': 'ADU and oil price'},
    ],
    'layout': {
        'xaxis': {'title': 'Oil Price', 'type': 'log'},
        'yaxis': {'title': "AUD/USD"}
    }
}


url = py.plot(fig, filename='pandas/AUD_oil')
