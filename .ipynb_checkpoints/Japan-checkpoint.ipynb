# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm

# %% [markdown]
# # Read data

# %%
jpyusd=pd.read_csv('data/Japan/CURRFX-JPYUSD.csv')
jpyusd['Date'] = pd.to_datetime(jpyusd['Date'])
jpyusd=jpyusd.rename(columns = {'Rate':'JPY/USD'})

# %%
oil=pd.read_csv('data/commodity/Crude oil.csv')
oil=oil.rename(columns = {'[DateTime]':'Date',' [Close]':'Crude Oil Price'})
oil['Date'] = pd.to_datetime(oil['Date'])

# %%
iron=pd.read_csv('data/commodity/Iron Ore.csv')
iron=iron.rename(columns = {'[DateTime]':'Date',' [Close]':'Iron Ore Price'})
iron['Date'] = pd.to_datetime(iron['Date'])

# %%
aluminum=pd.read_csv('data/commodity/Aluminum.csv')
aluminum=aluminum.rename(columns = {'[DateTime]':'Date',' [Close]':'Aluminum Price'})
aluminum['Date'] = pd.to_datetime(aluminum['Date'])

# %%
japan_inflation=pd.read_csv('data/japan/Japan Core Inflation Rate.csv')
japan_inflation=japan_inflation.rename(columns = {'[DateTime]':'Date',' [Close]':'Japan Inflation Rate'})
japan_inflation['Date'] = pd.to_datetime(japan_inflation['Date'])

# %%
japan_stock=pd.read_csv('data/japan/Japan NIKKEI 225 Stock Market Index.csv')
japan_stock=japan_stock.rename(columns = {'[DateTime]':'Date',' [Close]':'Stock Market Index'})
japan_stock['Date'] = pd.to_datetime(japan_stock['Date'])

# %%
japan_gdp_growth=pd.read_csv('data/japan/Japan GDP Growth Rate.csv')
japan_gdp_growth=japan_gdp_growth.rename(columns = {'[DateTime]':'Date',' [Close]':'GDP Growth Rate'})
japan_gdp_growth['Date'] = pd.to_datetime(japan_gdp_growth['Date'])

# %%
japan_bot=pd.read_csv('data/japan/Japan Balance of Trade.csv')
japan_bot=japan_bot.rename(columns = {'[DateTime]':'Date',' [Close]':'Balance of Trade'})
japan_bot['Date'] = pd.to_datetime(japan_bot['Date'])

# %%
japan_interest_rate=pd.read_csv('data/japan/Japan Interest Rate.csv')
japan_interest_rate=japan_interest_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'Interest Rate'})
japan_interest_rate['Date'] = pd.to_datetime(japan_interest_rate['Date'])

# %%
usdx=pd.read_csv('/Users/tongshan/Desktop/final/data/United States Dollar.csv')
usdx=usdx.rename(columns = {'[DateTime]':'Date',' [Close]':'USDX'})
usdx['Date'] = pd.to_datetime(usdx['Date'])

# %%
us_federal_fund_rate=pd.read_csv('/Users/tongshan/Desktop/final/data/United States Fed Funds Rate.csv')
us_federal_fund_rate=us_federal_fund_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'US Fed Funds Rate'})
us_federal_fund_rate['Date'] = pd.to_datetime(us_federal_fund_rate['Date'])

# %% [markdown]
# # Merge all data

# %%
jap_oil=jpyusd.merge(oil)
jap_oil_al=jap_oil.merge(aluminum)
jap_commodity=jap_oil_al.merge(iron)
jap_commodity
# Out:
# 1077 2012-01-16  0.012964            99.68         2127.50           140.5
# 1078 2012-01-13  0.012964            98.69         2113.75           142.2
# 1079 2012-01-12  0.012964            99.03         2133.75           142.2
# 1080 2012-01-11  0.012964           100.89         2135.00           142.2
# 1081 2012-01-10  0.012964           102.24         2137.50           142.3
# 1082 2012-01-09  0.012964           101.31         2085.75           140.0
# 1083 2012-01-06  0.012964           101.56         2046.75           140.0
# 1084 2012-01-05  0.012964           101.81         2014.00           139.9
# 1085 2012-01-04  0.012964           103.22         2041.25           138.8
# 1086 2012-01-03  0.012964           102.96         2054.50           138.3
# 1087 2012-01-02  0.012964            98.83         1994.50           138.5
#
# [1088 rows x 5 columns]

# %%
jap_commodity_inf=jap_commodity.merge(japan_inflation, how='outer')
jap_commodity_inf_stock=jap_commodity_inf.merge(japan_stock)
jap_commodity_inf_stock_gdp=jap_commodity_inf_stock.merge(japan_gdp_growth, how='outer')
jap_commodity_inf_stock_gdp_bot=jap_commodity_inf_stock_gdp.merge(japan_bot, how='outer')
jap_commodity_inf_stock_gdp_bot_interest=jap_commodity_inf_stock_gdp_bot.merge(japan_interest_rate, how='outer')
jap_commodity_inf_stock_gdp_bot_interest_usfund=jap_commodity_inf_stock_gdp_bot_interest.merge(us_federal_fund_rate, how='outer')

jap_all=jap_commodity_inf_stock_gdp_bot_interest_usfund.merge(usdx,how='outer')

# %% [markdown]
# ### Set date as index

# %%
jap_all=jap_all.sort_values('Date', ascending=False)

# %%
jap_all=jap_all.set_index('Date')

# %% [markdown]
# ### Fill all NaNs and drop unwanted rows

# %%
jap_all['Japan Inflation Rate']=jap_all['Japan Inflation Rate'].fillna(method='ffill')
jap_all['GDP Growth Rate']=jap_all['GDP Growth Rate'].fillna(method='ffill')
jap_all['Balance of Trade']=jap_all['Balance of Trade'].fillna(method='ffill')
jap_all['Interest Rate']=jap_all['Interest Rate'].fillna(method='bfill')
jap_all['US Fed Funds Rate']=jap_all['US Fed Funds Rate'].fillna(method='bfill')

# %%
jap_all.dropna(inplace=True)

# %%
jap_all
# Out:
#              JPY/USD  Crude Oil Price  Aluminum Price  Iron Ore Price  \
# Date
# 2015-12-31  0.008261            37.04         1501.00            42.9
# 2015-12-30  0.008261            36.60         1534.00            42.5
# 2015-12-29  0.008261            37.87         1525.00            41.4
# 2015-12-28  0.008261            36.81         1532.00            40.5
# 2015-12-24  0.008261            38.10         1540.50            40.2
# 2015-12-22  0.008261            36.14         1506.50            40.2
# 2015-12-21  0.008239            34.74         1515.00            39.4
# 2015-12-18  0.008239            34.73         1506.00            39.3
# 2015-12-17  0.008239            34.95         1476.00            38.5
# 2015-12-16  0.008239            35.52         1486.00            38.2
# 2015-12-15  0.008261            37.35         1471.00            37.5
# 2015-12-14  0.008261            36.31         1491.50            37.5
# 2015-12-11  0.008161            35.62         1482.00            37.0
# 2015-12-10  0.008161            36.76         1491.00            37.5
fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.415
# Model:                            OLS   Adj. R-squared:                  0.414
# Method:                 Least Squares   F-statistic:                     717.9
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          5.30e-120
# Time:                        23:38:17   Log-Likelihood:                 5389.9
# No. Observations:                1016   AIC:                        -1.078e+04
# Df Residuals:                    1014   BIC:                        -1.077e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.0063      0.000     42.213      0.000         0.006     0.007
# Crude Oil Price  4.608e-05   1.72e-06     26.793      0.000      4.27e-05  4.95e-05
# ==============================================================================
# Omnibus:                      129.312   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.605
# Skew:                           0.885   Prob(JB):                     1.46e-32
# Kurtosis:                       2.425   Cond. No.                         340.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = jap_all['Aluminum Price']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     774.8
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          3.87e-127
# Time:                        23:38:17   Log-Likelihood:                 5406.3
# No. Observations:                1016   AIC:                        -1.081e+04
# Df Residuals:                    1014   BIC:                        -1.080e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const             -0.0011      0.000     -2.720      0.007        -0.002    -0.000
# Aluminum Price  6.065e-06   2.18e-07     27.836      0.000      5.64e-06  6.49e-06
# ==============================================================================
# Omnibus:                        3.055   Durbin-Watson:                   0.014
# Prob(Omnibus):                  0.217   Jarque-Bera (JB):                3.109
# Skew:                           0.118   Prob(JB):                        0.211
# Kurtosis:                       2.866   Cond. No.                     2.02e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = jap_all['Iron Ore Price']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.562
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     1300.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          7.71e-184
# Time:                        23:38:17   Log-Likelihood:                 5537.0
# No. Observations:                1016   AIC:                        -1.107e+04
# Df Residuals:                    1014   BIC:                        -1.106e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const              0.0066      0.000     63.097      0.000         0.006     0.007
# Iron Ore Price  3.423e-05    9.5e-07     36.050      0.000      3.24e-05  3.61e-05
# ==============================================================================
# Omnibus:                      134.516   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.968
# Skew:                           1.029   Prob(JB):                     1.53e-41
# Kurtosis:                       3.452   Cond. No.                         348.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = jap_all['Japan Inflation Rate']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     173.0
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           1.34e-36
# Time:                        23:38:18   Log-Likelihood:                 5198.0
# No. Observations:                1016   AIC:                        -1.039e+04
# Df Residuals:                    1014   BIC:                        -1.038e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# const                    0.0105   5.63e-05    187.459      0.000         0.010     0.011
# Japan Inflation Rate    -0.0005   3.72e-05    -13.153      0.000        -0.001    -0.000
# ==============================================================================
# Omnibus:                      157.073   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.096
# Skew:                          -0.163   Prob(JB):                     1.19e-09
# Kurtosis:                       2.071   Cond. No.                         2.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = jap_all['Stock Market Index']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                 2.391e+04
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:38:18   Log-Likelihood:                 6744.6
# No. Observations:                1016   AIC:                        -1.349e+04
# Df Residuals:                    1014   BIC:                        -1.348e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# const                  0.0160   3.95e-05    405.429      0.000         0.016     0.016
# Stock Market Index -4.118e-07   2.66e-09   -154.640      0.000     -4.17e-07 -4.07e-07
# ==============================================================================
# Omnibus:                       54.298   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.001
# Skew:                          -0.067   Prob(JB):                     1.67e-05
# Kurtosis:                       2.292   Cond. No.                     5.90e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.9e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = jap_all['GDP Growth Rate']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     4.664
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):             0.0310
# Time:                        23:38:18   Log-Likelihood:                 5120.3
# No. Observations:                1016   AIC:                        -1.024e+04
# Df Residuals:                    1014   BIC:                        -1.023e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.0101   4.96e-05    204.200      0.000         0.010     0.010
# GDP Growth Rate    -0.0001   6.03e-05     -2.160      0.031        -0.000 -1.19e-05
# ==============================================================================
# Omnibus:                      334.591   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.038
# Skew:                           0.422   Prob(JB):                     1.13e-17
# Kurtosis:                       1.936   Cond. No.                         1.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = jap_all['Balance of Trade']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     10.79
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):            0.00106
# Time:                        23:38:19   Log-Likelihood:                 5123.3
# No. Observations:                1016   AIC:                        -1.024e+04
# Df Residuals:                    1014   BIC:                        -1.023e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                0.0099      8e-05    123.884      0.000         0.010     0.010
# Balance of Trade -2.941e-07   8.95e-08     -3.285      0.001      -4.7e-07 -1.18e-07
# ==============================================================================
# Omnibus:                      238.104   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.706
# Skew:                           0.579   Prob(JB):                     1.00e-21
# Kurtosis:                       2.028   Cond. No.                     1.46e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = jap_all['Interest Rate']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):                nan
# Time:                        23:38:19   Log-Likelihood:                 3213.5
# No. Observations:                1016   AIC:                            -6427.
# Df Residuals:                    1016   BIC:                            -6427.
# Df Model:                           0
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Interest Rate          0          0        nan        nan             0         0
# ==============================================================================
# Omnibus:                      286.811   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.574
# Skew:                           0.438   Prob(JB):                     1.43e-17
# Kurtosis:                       1.968   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X = jap_all['US Fed Funds Rate']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     14.37
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           0.000159
# Time:                        23:38:19   Log-Likelihood:                 5125.1
# No. Observations:                1016   AIC:                        -1.025e+04
# Df Residuals:                    1014   BIC:                        -1.024e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# const                 0.0120      0.001     23.866      0.000         0.011     0.013
# US Fed Funds Rate    -0.0075      0.002     -3.791      0.000        -0.011    -0.004
# ==============================================================================
# Omnibus:                      265.977   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.880
# Skew:                           0.429   Prob(JB):                     5.49e-17
# Kurtosis:                       1.983   Cond. No.                         43.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = jap_all['USDX']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     1271.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          4.21e-181
# Time:                        23:38:20   Log-Likelihood:                 5530.7
# No. Observations:                1016   AIC:                        -1.106e+04
# Df Residuals:                    1014   BIC:                        -1.105e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0249      0.000     59.874      0.000         0.024     0.026
# USDX          -0.0002   4.86e-06    -35.652      0.000        -0.000    -0.000
# ==============================================================================
# Omnibus:                      121.515   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.794
# Skew:                           0.642   Prob(JB):                     7.08e-21
# Kurtosis:                       2.262   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = jap_all['USDX']
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     1271.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          4.21e-181
# Time:                        23:38:20   Log-Likelihood:                 5530.7
# No. Observations:                1016   AIC:                        -1.106e+04
# Df Residuals:                    1014   BIC:                        -1.105e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0249      0.000     59.874      0.000         0.024     0.026
# USDX          -0.0002   4.86e-06    -35.652      0.000        -0.000    -0.000
# ==============================================================================
# Omnibus:                      121.515   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.794
# Skew:                           0.642   Prob(JB):                     7.08e-21
# Kurtosis:                       2.262   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = jap_all.drop(['JPY/USD'], axis=1)
y = jap_all['JPY/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JPY/USD   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.277e+05
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:38:21   Log-Likelihood:                 6790.4
# No. Observations:                1016   AIC:                        -1.356e+04
# Df Residuals:                    1007   BIC:                        -1.352e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Crude Oil Price       2.872e-05   1.18e-06     24.407      0.000      2.64e-05   3.1e-05
# Aluminum Price        9.288e-07   8.34e-08     11.139      0.000      7.65e-07  1.09e-06
# Iron Ore Price        7.454e-07   8.03e-07      0.928      0.353      -8.3e-07  2.32e-06
# Japan Inflation Rate    -0.0001   1.28e-05     -8.115      0.000        -0.000 -7.89e-05
# Stock Market Index   -4.482e-07   6.77e-09    -66.231      0.000     -4.61e-07 -4.35e-07
# GDP Growth Rate         -0.0002   1.44e-05    -11.575      0.000        -0.000    -0.000
# Balance of Trade      -2.13e-07   2.31e-08     -9.235      0.000     -2.58e-07 -1.68e-07
# Interest Rate        -5.882e-18   1.93e-18     -3.053      0.002     -9.66e-18  -2.1e-18
# US Fed Funds Rate        0.0012      0.000      3.087      0.002         0.000     0.002
# USDX                     0.0001   2.64e-06     53.385      0.000         0.000     0.000
# ==============================================================================
# Omnibus:                        9.649   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                6.523
# Skew:                           0.002   Prob(JB):                       0.0383
# Kurtosis:                       2.607   Cond. No.                     1.11e+23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.85e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # Plotting

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('Kj2921812', 'exatkr0578')

# %%
jpyusd.head()

trace = go.Scatter( x=jpyusd['Date'], y=jpyusd['JPY/USD'] )
data = [trace]

url = py.plot(data, filename='JPY/USD from 2012 to now')

# %%
jap_alloil = jap_all['Crude Oil Price']
jap_alljpy = jap_all['JPY/USD']
jap_all.head(2)

fig = {
    'data': [
  		{
  			'x': jap_alloil, 
        	'y': jap_alljpy, 
        	'text': jap_all.index, 
        	'mode': 'markers', 
        	'name': 'JAP and oil price'},
    ],
    'layout': {
        'xaxis': {'title': 'Oil Price', 'type': 'log'},
        'yaxis': {'title': "JPY/USD"}
    }
}


url = py.plot(fig, filename='pandas/JPY_oil')
