# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm

# %% [markdown]
# # Read data

# %%
cadusd=pd.read_csv('data/canada/CURRFX-CADUSD.csv')
cadusd['Date'] = pd.to_datetime(cadusd['Date'])
cadusd=cadusd.rename(columns = {'Rate':'CAD/USD'})

# %%
oil=pd.read_csv('data/commodity/Crude oil.csv')
oil=oil.rename(columns = {'[DateTime]':'Date',' [Close]':'Crude Oil Price'})
oil['Date'] = pd.to_datetime(oil['Date'])

# %%
iron=pd.read_csv('data/commodity/Iron Ore.csv')
iron=iron.rename(columns = {'[DateTime]':'Date',' [Close]':'Iron Ore Price'})
iron['Date'] = pd.to_datetime(iron['Date'])

# %%
canada_inflation=pd.read_csv('data/canada/Canada Core Inflation Rate.csv')
canada_inflation=canada_inflation.rename(columns = {'[DateTime]':'Date',' [Close]':'Canadian Inflation Rate'})
canada_inflation['Date'] = pd.to_datetime(canada_inflation['Date'])

# %%
aluminum=pd.read_csv('data/commodity/Aluminum.csv')
aluminum=aluminum.rename(columns = {'[DateTime]':'Date',' [Close]':'Aluminum Price'})
aluminum['Date'] = pd.to_datetime(aluminum['Date'])

# %%
canada_stock=pd.read_csv('data/canada/Canada S&P TSX Toronto Stock Market Index.csv')
canada_stock=canada_stock.rename(columns = {'[DateTime]':'Date',' [Close]':'Stock Market Index'})
canada_stock['Date'] = pd.to_datetime(canada_stock['Date'])

# %%
canada_gdp_growth=pd.read_csv('data/canada/Canada GDP Growth Rate.csv')
canada_gdp_growth=canada_gdp_growth.rename(columns = {'[DateTime]':'Date',' [Close]':'GDP Growth Rate'})
canada_gdp_growth['Date'] = pd.to_datetime(canada_gdp_growth['Date'])

# %%
canada_bot=pd.read_csv('data/canada/Canada Balance of Trade.csv')
canada_bot=canada_bot.rename(columns = {'[DateTime]':'Date',' [Close]':'Balance of Trade'})
canada_bot['Date'] = pd.to_datetime(canada_bot['Date'])

# %%
canada_interest_rate=pd.read_csv('data/canada/Canada Interest Rate.csv')
canada_interest_rate=canada_interest_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'Interest Rate'})
canada_interest_rate['Date'] = pd.to_datetime(canada_interest_rate['Date'])

# %%
usdx=pd.read_csv('data/United States Dollar.csv')
usdx=usdx.rename(columns = {'[DateTime]':'Date',' [Close]':'USDX'})
usdx['Date'] = pd.to_datetime(usdx['Date'])

# %%
us_federal_fund_rate=pd.read_csv('data/United States Fed Funds Rate.csv')
us_federal_fund_rate=us_federal_fund_rate.rename(columns = {'[DateTime]':'Date',' [Close]':'US Fed Funds Rate'})
us_federal_fund_rate['Date'] = pd.to_datetime(us_federal_fund_rate['Date'])

# %% [markdown]
# # Merge all data

# %%
cad_oil=cadusd.merge(oil)
cad_oil_al=cad_oil.merge(aluminum)
cad_commodity=cad_oil_al.merge(iron)
cad_commodity
# Out:
#            Date   CAD/USD  Crude Oil Price  Aluminum Price  Iron Ore Price
# 0    2016-03-04  0.745859            36.30         1586.50            52.4
# 1079 2012-01-12  0.982375            99.03         2133.75           142.2
# 1080 2012-01-11  0.982124           100.89         2135.00           142.2
# 1081 2012-01-10  0.977737           102.24         2137.50           142.3
# 1082 2012-01-09  0.974938           101.31         2085.75           140.0
# 1083 2012-01-06  0.981251           101.56         2046.75           140.0
# 1084 2012-01-05  0.985405           101.81         2014.00           139.9
# 1085 2012-01-04  0.987207           103.22         2041.25           138.8
# 1086 2012-01-03  0.984529           102.96         2054.50           138.3
# 1087 2012-01-02  0.980536            98.83         1994.50           138.5
#
# [1088 rows x 5 columns]

# %%
cad_commodity_inf=cad_commodity.merge(canada_inflation, how='outer')
cad_commodity_inf_stock=cad_commodity_inf.merge(canada_stock)
cad_commodity_inf_stock_gdp=cad_commodity_inf_stock.merge(canada_gdp_growth, how='outer')
cad_commodity_inf_stock_gdp_bot=cad_commodity_inf_stock_gdp.merge(canada_bot, how='outer')
cad_commodity_inf_stock_gdp_bot_interest=cad_commodity_inf_stock_gdp_bot.merge(canada_interest_rate, how='outer')
cad_commodity_inf_stock_gdp_bot_interest_usfund=cad_commodity_inf_stock_gdp_bot_interest.merge(us_federal_fund_rate, how='outer')
cad_all=cad_commodity_inf_stock_gdp_bot_interest_usfund.merge(usdx)
cad_all
# Out:
#            Date   CAD/USD  Crude Oil Price  Aluminum Price  Iron Ore Price  \
# 0    2016-03-04  0.745859            36.30         1586.50            52.4
# 1    2016-03-03  0.744684            34.73         1575.00            51.7
# 2    2016-03-02  0.742812            34.63         1590.50            51.6
# 3    2016-03-01  0.740094            33.86         1579.00            50.4
# 4    2016-02-29  0.738836            33.85         1572.00            48.9
# 5    2016-02-26  0.736298            32.82         1561.00            49.0
# 6    2016-02-25  0.729311            33.00         1558.50            49.2
# 7    2016-02-24  0.726167            32.21         1571.00            50.2
# 8    2016-02-23  0.727925            31.37         1547.00            50.5
# 9    2016-02-22  0.727180            33.31         1575.50            50.3
# 10   2016-02-19  0.727738            29.83         1562.75            47.0
# 11   2016-02-18  0.727934            30.54         1522.00            46.5
# 12   2016-02-17  0.723757            31.45         1523.00            45.8
# 13   2016-02-16  0.723718            29.19         1528.00            46.1
# 14   2016-02-15  0.721667            30.61         1506.00            45.6
# 15   2016-02-12  0.718391            29.16         1501.00            43.2
# 16   2016-02-11  0.717900            27.30         1484.50            44.5
# 17   2016-02-10  0.719526            27.36         1484.00            44.5
# 18   2016-02-09  0.719323            28.36         1481.00            44.7
# 19   2016-02-08  0.721763            30.19         1504.50            44.7
# 20   2016-02-05  0.726860            30.84         1495.00            44.7
# 21   2016-02-04  0.723676            31.54         1535.00            44.7
# 22   2016-02-03  0.714874            31.69         1527.00            44.0
# 23   2016-02-02  0.713521            29.63         1499.00            43.1
# 24   2016-02-01  0.713521            31.46         1519.50            42.5
# 25   2016-01-29  0.711711            33.73         1515.00            41.5
# 26   2016-01-28  0.709815            33.52         1512.50            41.5
# 27   2016-01-27  0.706992            32.30         1526.00            41.3
# ...                      ...            ...                ...     ...
# 2012-02-10               NaN            NaN                NaN  79.110
# 2012-02-09               NaN            NaN                NaN  78.570
# 2012-02-08               NaN            NaN                NaN  78.640
# 2012-02-07               NaN            NaN                NaN  78.580
# 2012-02-06               NaN            NaN                NaN  79.070
# 2012-02-03               NaN            NaN                NaN  78.920
# 2012-02-02               NaN            NaN                NaN  78.990
# 2012-02-01               NaN            NaN                NaN  78.920
# 2012-01-31             -34.6            1.0                NaN  79.290
# 2012-01-30               NaN            NaN                NaN  79.170
# 2012-01-27               NaN            NaN                NaN  78.900
# 2012-01-26               NaN            NaN                NaN  79.390
# 2012-01-25               NaN            NaN               0.25  79.580
# 2012-01-24               NaN            NaN                NaN  79.870
# 2012-01-23               NaN            NaN                NaN  79.780
# 2012-01-20               NaN            NaN                NaN  80.220
# 2012-01-19               NaN            NaN                NaN  80.220
# 2012-01-18               NaN            NaN                NaN  80.610
# 2012-01-17               NaN            NaN                NaN  81.180
# 2012-01-16               NaN            NaN                NaN  81.510
# 2012-01-13               NaN            NaN                NaN  81.510
# 2012-01-12               NaN            NaN                NaN  80.770
# 2012-01-11               NaN            NaN                NaN  81.350
# 2012-01-10               NaN            NaN                NaN  80.800
# 2012-01-09               NaN            NaN                NaN  81.050
# 2012-01-06               NaN            NaN                NaN  81.250
# 2012-01-05               NaN            NaN                NaN  80.940
# 2012-01-04               NaN            NaN                NaN  80.130
# 2012-01-03               NaN            NaN                NaN  79.610
# 2012-01-02               NaN            NaN                NaN  80.180
#
# [1087 rows x 11 columns]

# %% [markdown]
# ### Fill all NaNs and drop unwanted rows

# %%
cad_all['Canadian Inflation Rate']=cad_all['Canadian Inflation Rate'].fillna(method='ffill')
cad_all['GDP Growth Rate']=cad_all['GDP Growth Rate'].fillna(method='ffill')
cad_all['Balance of Trade']=cad_all['Balance of Trade'].fillna(method='ffill')
cad_all['Interest Rate']=cad_all['Interest Rate'].fillna(method='bfill')
cad_all['US Fed Funds Rate']=cad_all['US Fed Funds Rate'].fillna(method='bfill')

# %%
cad_all.dropna(inplace=True)

# %%
cad_all
# Out:
#              CAD/USD  Crude Oil Price  Aluminum Price  Iron Ore Price  \
# Date
# 2015-12-31  0.721075            37.04         1501.00            42.9
# 2015-12-30  0.720972            36.60         1534.00            42.5
# 2015-12-29  0.720839            37.87         1525.00            41.4
# 2015-12-28  0.721504            36.81         1532.00            40.5
# 2015-12-24  0.720859            38.10         1540.50            40.2
# 2015-12-23  0.718446            37.50         1543.00            40.2
# 2015-12-22  0.717163            36.14         1506.50            40.2
# 2015-12-21  0.717283            34.74         1515.00            39.4
# 2015-12-18  0.719442            34.73         1506.00            39.3
# 2015-12-17  0.723973            34.95         1476.00            38.5
# 2015-12-16  0.727691            35.52         1486.00            38.2
# 2015-12-15  0.728790            37.35         1471.00            37.5
# 2015-12-14  0.729481            36.31         1491.50            37.5
# 2015-12-11  0.733736            35.62         1482.00            37.0
# 2015-12-10  0.736886            36.76         1491.00            37.5
# 2015-12-16            -630.8            0.5               0.50   97.871
# 2015-12-15            -630.8            0.5               0.25   98.217
# 2015-12-14            -630.8            0.5               0.25   97.604
# 2015-12-11            -630.8            0.5               0.25   97.565
# 2015-12-10            -630.8            0.5               0.25   97.939
# 2015-12-09            -630.8            0.5               0.25   97.345
# 2015-12-08            -630.8            0.5               0.25   98.474
# 2015-12-07            -630.8            0.5               0.25   98.655
# 2015-12-04            -630.8            0.5               0.25   98.354
# 2015-12-03            -630.8            0.5               0.25   97.621
# 2015-12-02            -630.8            0.5               0.25   99.993
# 2015-12-01            -630.8            0.5               0.25   99.795
# 2015-11-30           -1728.8            0.5               0.25  100.170
# 2015-11-27           -1728.8            0.5               0.25  100.020
# 2015-11-26           -1728.8            0.5               0.25   99.795
# 2015-11-25           -1728.8            0.5               0.25   99.795
# 2015-11-24           -1728.8            0.5               0.25   99.527
# 2015-11-23           -1728.8            0.5               0.25   99.803
# 2015-11-20           -1728.8            0.5               0.25   99.565
# 2015-11-19           -1728.8            0.5               0.25   98.989
# ...                      ...            ...                ...      ...
# 2012-03-12            -740.9            1.0               0.25   79.890
# 2012-03-09            -740.9            1.0               0.25   80.040
# 2012-03-08            -740.9            1.0               0.25   79.140
# 2012-03-07            -740.9            1.0               0.25   79.710
# 2012-03-06            -740.9            1.0               0.25   79.870
# 2012-03-05            -740.9            1.0               0.25   79.300
# 2012-03-02            -740.9            1.0               0.25   79.400
# 2012-03-01            -740.9            1.0               0.25   78.790
# 2012-02-29              -1.0            1.0               0.25   78.740
# 2012-02-28              -1.0            1.0               0.25   78.270
# 2012-02-27              -1.0            1.0               0.25   78.570
# 2012-02-24              -1.0            1.0               0.25   78.350
# 2012-02-23              -1.0            1.0               0.25   78.820
# 2012-02-22              -1.0            1.0               0.25   79.210
# 2012-02-21              -1.0            1.0               0.25   79.040
# 2012-02-20              -1.0            1.0               0.25   79.330
# 2012-02-17              -1.0            1.0               0.25   79.330
# 2012-02-16              -1.0            1.0               0.25   79.350
# 2012-02-15              -1.0            1.0               0.25   79.670
# 2012-02-14              -1.0            1.0               0.25   79.580
# 2012-02-13              -1.0            1.0               0.25   78.950
# 2012-02-10              -1.0            1.0               0.25   79.110
# 2012-02-09              -1.0            1.0               0.25   78.570
# 2012-02-08              -1.0            1.0               0.25   78.640
# 2012-02-07              -1.0            1.0               0.25   78.580
# 2012-02-06              -1.0            1.0               0.25   79.070
# 2012-02-03              -1.0            1.0               0.25   78.920
# 2012-02-02              -1.0            1.0               0.25   78.990
# 2012-02-01              -1.0            1.0               0.25   78.920
# 2012-01-31             -34.6            1.0               0.25   79.290
#
# [1021 rows x 11 columns]

# %% [markdown]
# ### Save as csv

# %%
cad_all.to_csv('canada.csv')

# %% [markdown]
# # Analysis

# %%
X = cad_all['Crude Oil Price']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     3025.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          2.91e-307
# Time:                        23:37:34   Log-Likelihood:                 1756.5
# No. Observations:                1021   AIC:                            -3509.
# Df Residuals:                    1019   BIC:                            -3499.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.6326      0.005    119.419      0.000         0.622     0.643
# Crude Oil Price     0.0034   6.16e-05     54.999      0.000         0.003     0.004
# ==============================================================================
# Omnibus:                      139.464   Durbin-Watson:                   0.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.891
# Skew:                           0.211   Prob(JB):                     8.01e-10
# Kurtosis:                       2.102   Cond. No.                         336.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['Aluminum Price']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     1019.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          1.64e-155
# Time:                        23:37:35   Log-Likelihood:                 1406.6
# No. Observations:                1021   AIC:                            -2809.
# Df Residuals:                    1019   BIC:                            -2799.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const              0.2512      0.021     12.040      0.000         0.210     0.292
# Aluminum Price     0.0004   1.12e-05     31.916      0.000         0.000     0.000
# ==============================================================================
# Omnibus:                     1003.447   Durbin-Watson:                   0.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.800
# Skew:                          -0.233   Prob(JB):                     9.43e-17
# Kurtosis:                       1.768   Cond. No.                     2.02e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = cad_all['Iron Ore Price']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     4183.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:37:35   Log-Likelihood:                 1885.1
# No. Observations:                1021   AIC:                            -3766.
# Df Residuals:                    1019   BIC:                            -3756.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const              0.6825      0.004    180.706      0.000         0.675     0.690
# Iron Ore Price     0.0022   3.47e-05     64.673      0.000         0.002     0.002
# ==============================================================================
# Omnibus:                      118.161   Durbin-Watson:                   0.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.331
# Skew:                           0.874   Prob(JB):                     3.41e-36
# Kurtosis:                       3.886   Cond. No.                         344.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['Stock Market Index']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     663.8
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          4.01e-113
# Time:                        23:37:36   Log-Likelihood:                 1309.0
# No. Observations:                1021   AIC:                            -2614.
# Df Residuals:                    1019   BIC:                            -2604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# const                  1.5275      0.024     63.921      0.000         1.481     1.574
# Stock Market Index -4.551e-05   1.77e-06    -25.764      0.000      -4.9e-05  -4.2e-05
# ==============================================================================
# Omnibus:                      213.250   Durbin-Watson:                   0.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              370.399
# Skew:                          -1.307   Prob(JB):                     3.70e-81
# Kurtosis:                       4.370   Cond. No.                     1.54e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = cad_all['Canadian Inflation Rate']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     718.1
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          3.68e-120
# Time:                        23:37:37   Log-Likelihood:                 1325.2
# No. Observations:                1021   AIC:                            -2646.
# Df Residuals:                    1019   BIC:                            -2637.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# const                       1.1251      0.008    138.260      0.000         1.109     1.141
# Canadian Inflation Rate    -0.1221      0.005    -26.797      0.000        -0.131    -0.113
# ==============================================================================
# Omnibus:                        5.740   Durbin-Watson:                   0.006
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                7.231
# Skew:                          -0.029   Prob(JB):                       0.0269
# Kurtosis:                       3.408   Cond. No.                         9.11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['GDP Growth Rate']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     32.96
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           1.24e-08
# Time:                        23:37:37   Log-Likelihood:                 1069.1
# No. Observations:                1021   AIC:                            -2134.
# Df Residuals:                    1019   BIC:                            -2124.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.8977      0.004    228.954      0.000         0.890     0.905
# GDP Growth Rate     0.0412      0.007      5.741      0.000         0.027     0.055
# ==============================================================================
# Omnibus:                      103.905   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.070
# Skew:                          -0.498   Prob(JB):                     4.50e-15
# Kurtosis:                       2.250   Cond. No.                         3.19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['Balance of Trade']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     143.1
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           5.93e-31
# Time:                        23:37:38   Log-Likelihood:                 1120.0
# No. Observations:                1021   AIC:                            -2236.
# Df Residuals:                    1019   BIC:                            -2226.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                0.9340      0.003    308.953      0.000         0.928     0.940
# Balance of Trade  2.343e-05   1.96e-06     11.962      0.000      1.96e-05  2.73e-05
# ==============================================================================
# Omnibus:                      123.385   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.540
# Skew:                          -0.370   Prob(JB):                     2.37e-12
# Kurtosis:                       2.158   Cond. No.                     1.84e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = cad_all['Interest Rate']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     3013.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          1.29e-306
# Time:                        23:37:38   Log-Likelihood:                 1755.1
# No. Observations:                1021   AIC:                            -3506.
# Df Residuals:                    1019   BIC:                            -3496.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# const             0.5157      0.007     69.826      0.000         0.501     0.530
# Interest Rate     0.4376      0.008     54.891      0.000         0.422     0.453
# ==============================================================================
# Omnibus:                      124.416   Durbin-Watson:                   0.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.499
# Skew:                          -0.319   Prob(JB):                     2.94e-11
# Kurtosis:                       2.145   Cond. No.                         10.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['US Fed Funds Rate']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     58.99
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):           3.71e-14
# Time:                        23:37:39   Log-Likelihood:                 1081.6
# No. Observations:                1021   AIC:                            -2159.
# Df Residuals:                    1019   BIC:                            -2149.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# const                 1.1118      0.026     42.990      0.000         1.061     1.163
# US Fed Funds Rate    -0.7820      0.102     -7.680      0.000        -0.982    -0.582
# ==============================================================================
# Omnibus:                      155.076   Durbin-Watson:                   0.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.550
# Skew:                          -0.668   Prob(JB):                     1.98e-23
# Kurtosis:                       2.181   Cond. No.                         41.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all['USDX']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     5326.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:37:39   Log-Likelihood:                 1986.5
# No. Observations:                1021   AIC:                            -3969.
# Df Residuals:                    1019   BIC:                            -3959.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.9077      0.014    139.689      0.000         1.881     1.935
# USDX          -0.0116      0.000    -72.976      0.000        -0.012    -0.011
# ==============================================================================
# Omnibus:                       82.535   Durbin-Watson:                   0.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.606
# Skew:                          -0.502   Prob(JB):                     4.19e-14
# Kurtosis:                       2.336   Cond. No.                     1.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = cad_all['Crude Oil Price']
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     3025.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):          2.91e-307
# Time:                        23:37:40   Log-Likelihood:                 1756.5
# No. Observations:                1021   AIC:                            -3509.
# Df Residuals:                    1019   BIC:                            -3499.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const               0.6326      0.005    119.419      0.000         0.622     0.643
# Crude Oil Price     0.0034   6.16e-05     54.999      0.000         0.003     0.004
# ==============================================================================
# Omnibus:                      139.464   Durbin-Watson:                   0.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.891
# Skew:                           0.211   Prob(JB):                     8.01e-10
# Kurtosis:                       2.102   Cond. No.                         336.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = cad_all.drop(['CAD/USD'], axis=1)
y = cad_all['CAD/USD']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CAD/USD   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     3853.
# Date:                Wed, 16 Mar 2016   Prob (F-statistic):               0.00
# Time:                        23:37:41   Log-Likelihood:                 2925.0
# No. Observations:                1021   AIC:                            -5828.
# Df Residuals:                    1010   BIC:                            -5774.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# const                       0.9569      0.032     29.662      0.000         0.894     1.020
# Crude Oil Price             0.0010   7.74e-05     12.821      0.000         0.001     0.001
# Aluminum Price              0.0001   4.23e-06     34.129      0.000         0.000     0.000
# Iron Ore Price          -9.731e-05   3.82e-05     -2.546      0.011        -0.000 -2.23e-05
# Canadian Inflation Rate    -0.0291      0.002    -16.267      0.000        -0.033    -0.026
# Stock Market Index      -2.251e-05   6.44e-07    -34.959      0.000     -2.38e-05 -2.12e-05
# GDP Growth Rate            -0.0073      0.001     -5.203      0.000        -0.010    -0.005
# Balance of Trade        -3.712e-07   6.31e-07     -0.588      0.556     -1.61e-06  8.67e-07
# Interest Rate               0.1237      0.007     18.259      0.000         0.110     0.137
# US Fed Funds Rate          -0.1770      0.018     -9.723      0.000        -0.213    -0.141
# USDX                       -0.0011      0.000     -3.839      0.000        -0.002    -0.001
# ==============================================================================
# Omnibus:                       13.062   Durbin-Watson:                   0.114
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               12.633
# Skew:                          -0.240   Prob(JB):                      0.00181
# Kurtosis:                       2.741   Cond. No.                     1.03e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Plotting

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('Kj2921812', 'exatkr0578')

# %%
cadusd.head()

trace = go.Scatter( x=cadusd['Date'], y=cadusd['CAD/USD'] )
data = [trace]

url = py.plot(data, filename='CAD/USD from 2012 to now')

# %%
cad_alloil = cad_all['Crude Oil Price']
cad_allcad = cad_all['CAD/USD']
cad_all.head(2)

fig = {
    'data': [
  		{
  			'x': cad_alloil, 
        	'y': cad_allcad, 
        	'text': cad_all.index, 
        	'mode': 'markers', 
        	'name': 'CAD and oil price'},
    ],
    'layout': {
        'xaxis': {'title': 'Oil Price', 'type': 'log'},
        'yaxis': {'title': "CAD/USD"}
    }
}


url = py.plot(fig, filename='pandas/cad_oilprice')
